# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Tarea 03: Exploración de datos </center></h1>
#
# **Fecha de Entrega:** 28 de octubre de 2025, a las 23:59.
#
# **Fecha de publicación**: 14 de octubre de 2025.
#
# **Formato de entrega:** Notebook ejecutado y comentado (`.ipynb`) en el módulo de Tarea 03 habilitado en Canvas.

# %% [markdown]
# ## Instrucciones
#
# - Esta Tarea debe desarrollarse de manera totalmente *individual*, de acuerdo a lo establecido en la sección de Integridad Académica en el programa del curso.
# - La Tarea debe ser desarrollada en lenguaje de programación Python y la entrega en formato Jupyter Notebook.
# - El desarrollo del Notebook debe ser claro y ordenado, incluyendo anotaciones (markdown) y comentarios que permitan seguir fácilmente el código y los pasos implementados a los correctores, y siguiendo buenas prácticas de programación. La presentación y claridad del notebook y código forman parte de la evaluación de la tarea.
# - Notebook **autocontenible** que:
#    - Ejecute sin errores todas las celdas.
#   - Contenga tanto el código como los comentarios y explicaciones necesarias.
#   - Incluya visualizaciones claras y correctamente etiquetadas.
# - No se aceptarán notebooks con celdas rotas o que dependan de rutas externas no indicadas en la tarea.
#
# - Deben hacer sus consultas y comentarios sobre la Tarea a través del canal de Tareas en el Foro del curso en Canvas.
#
# ---

# %% [markdown]
# ## 1. Objetivos
#
# - Aplicar los conceptos iniciales de manejo de datos y análisis exploratorio vistos en clases.
# - Practicar la lectura, limpieza y manipulación de datos en Python.
# - Desarrollar habilidades para visualizar y describir patrones y tendencias en conjuntos de datos reales.
# - Fomentar la capacidad de comunicar resultados de forma clara y fundamentada.
#
# ### 1.1 Objetivo educacional
#
# Esta Tarea tiene como objetivo que los estudiantes desarrollen la capacidad de manejar algunas de las librerías centrales para el desarrollo de Ciencia de Datos, con foco en la lectura y exploración de datos.
#
# Para los ejercicios a continuación, usted deberá leer, inspeccionar, manipular y graficar conjuntos de datos en distintos formatos, de manera de responder las preguntas de cada parte de la Tarea.
#
# ### 1.2 Pregunta de ciencia de datos
#
# En esta tarea vamos a analizar la distribución de vulneribilidad escolar para distintos establecimientos educacionales en Chile, desde enseñanza parvularia hasta enseñanza media. Específicamente, queremos entender cómo se comporta un índice de vulnerabilidad en relación a variables como ruralidad, tipo de dependencia y comuna del establecimiento.
#
# ---

# %% [markdown]
# ## 2. Datos
#
# En este estudio, trabajaremos con los resultados publicados anualmente sobre por la JUNAEB
# sobre vulnerabilidad de establecimientos educacionales en todo el territorio nacional. Estos resultados están disponibles en la siguiente página web:
#
# * Índices de Vulnerabilidad (JUNAEB): https://www.junaeb.cl/medicion-la-vulnerabilidad-ivm/
#
# Adicionalmente, para visualizar las variables, utilizaremos los mapas vectoriales que disponibiliza la Biblioteca del Congreso Nacional (BCN):
#
# * Mapoteca BCN: https://www.bcn.cl/siit/mapas_vectoriales/index_html
#
# ### 2.1 Descarga de datos y conceptos generales (1 punto)
#
# Acceda a los links entregados y descargue el set de datos del **Índice de Vulnerabilidad Multidimensional de Establecimientos Educacionales** para el año 2025. Este debería ser un documento XLSX con múltiples pestañas, incluyendo entre estas un índice que describe las columnas presentes en la base de datos.
# Descargue además los archivos correspondientes a la **División comunal: polígonos de las comunas de Chile**. Este se descarga en formato `.zip` y contiene archivos shapefile para visualizar las comunas del país.
#
# Investigue sobre este índice y responda de manera concisa:
# * ¿En qué consiste el IVM? ¿Qué rango de valores toma y qué significan?
# * ¿Cómo se obtiene el IVM de un establecimiento educacional?

# %% [markdown]
# Respuesta:
#
# ----------------------------------------------------------------------------------------------------------------
#
# Segun https://www.junaeb.cl/medicion-la-vulnerabilidad-ivm IVM es una medida generara a partir de la correlacion de variables que representnan las dimensiones o factores mas relevantes de un concepto de vulnerabilidad o observable, segun la trayectoria escolar del estudiante.
# Los puntajes oscilan entre 0 y 100, donde el valor mayor expresa la maxima vulnerabilidad posible
#
# ----------------------------------------------------------------------------------------------------------------
# Para poder obtener el IVM de un establecimiento educacional podemos utilizar las 'key' presente en las tablas
#
#
# 'DS_NOM_ESTABLE' - Nombre del establecimiento evaluado
#
# 'ID_REGION_ESTABLE' - Código de la región en que se ubica el establecimiento
#
# 'ID_COMUNA_ESTABLE' - Código de la comuna en que se ubica el establecimiento
#
# 'DS_COMUNA_ESTABLE' - Nombre de la comuna en que se ubica el establecimiento
#
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3. Lectura y limpieza de datos (1 punto)
#
# ### 3.1 Datos de establecimientos (0.5 puntos)
# El archivo descargado contiene información sobre establecimientos de cuatro tipos: Parvularia, Primer Ciclo Básica, Segundo Ciclo Básica y Media.
# Cargue los datos de los establecimientos en cuatro DataFrames distintos.
#
# Revise cada uno de sus sets de datos y haga un proceso de limpieza si lo considera necesario (manejo de valores nulos, duplicados, inválidos, transformación de tipos de datos, etc). De haberlos, identifique qué atributos son categóricos y transforme los tipos de columna de acuerdo a su decisión, mostrando todos los posibles valores de cada categoría.
#
# Justifique **todas** sus decisiones, **incluso** si decide no realizar una limpieza o transformación.
#
# Finalmente, responda:
#
# * a. ¿Cuántos establecimientos tiene cada set de datos?
# * b. ¿Cuánto espacio en memoria ocupan en total los 4 datasets?
# * c. ¿Cuántos estudiantes fueron evaluados en todo el país para cada nivel de enseñanza para el año 2025?

# %%
# Librerias :3 
import pandas as pd

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9E56-4120
#
#  Directory of c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3\data
#
# 10/25/2025  06:17 PM    <DIR>          .
# 10/25/2025  06:17 PM    <DIR>          ..
# 10/19/2025  10:15 PM        37,668,435 Comunas.zip
# 10/19/2025  10:15 PM         3,502,624 IVM_Establecimientos_2025-2.xlsx
#                2 File(s)     41,171,059 bytes
#                2 Dir(s)  23,664,734,208 bytes free

# %%
# %pwd
# Out:
# 'c:\\GIT HUB DESKO\\IMT2200-Lucas-Chicao\\Tareas\\Tarea 3\\data\\Comunas'

# %%
# %cd ..
# Out:
# c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3\data

# %%
# %cd Tarea 3
# Out:
# c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3

# %%
# %cd data
# Out:
# c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3\data

# %%
#Abriendo el DF
archivo = "IVM_Establecimientos_2025-2.xlsx"
hojas = pd.ExcelFile(archivo).sheet_names
#print(hojas)

df_parvularia = pd.read_excel(archivo, sheet_name=hojas[1])
df_ciclo1 = pd.read_excel(archivo, sheet_name=hojas[2])
df_ciclo2 = pd.read_excel(archivo, sheet_name=hojas[3])
df_media = pd.read_excel(archivo, sheet_name=hojas[4])

def mostrar_weas_Del_dataframio(df):
    print("Filas y columnas:", df.shape)
    print("Duplicados:", df.duplicated().sum())
    print("Nulos por columna:\n", df.isnull().sum())
    print("Tipos de datos:\n", df.dtypes)

# %% [markdown]
# # Limpieza de datos
#
# 1. No hay nulos xd
# 2. No hay Duplicados
# 3. No hay valores fuera de rango en
#
# No me fije en los valores porque de ser necesario lo modificare al momento de ocuparlos

# %%
# Nulos
nulos1 = df_parvularia.isnull().sum()
nulos2 = df_ciclo1.isnull().sum()
nulos3 = df_ciclo2.isnull().sum()
nulos4 = df_media.isnull().sum()
# print(nulos1)
# print(nulos2)
# print(nulos3)
# print(nulos4)

# %%
# Duplicados

dupli_1 =df_parvularia[df_parvularia.duplicated()]
dupli_2 =df_ciclo1[df_ciclo1.duplicated()]
dupli_3 =df_ciclo2[df_ciclo2.duplicated()]
dupli_4 =df_media[df_media.duplicated()]
#dupli_1
#dupli_2
#dupli_3
#dupli_4

# %%
# Valores DS_Ruralidad 
# use este simbolito ~ que es la 'negacion' ya que si no de otra forma tendria que usar apply y pos como que me da lata xDD

valores_invalidos1 = df_parvularia[~df_parvularia['DS_RURALIDAD'].isin(['Rural', 'Urbano'])]
valores_invalidos2 = df_ciclo1[~df_ciclo1['DS_RURALIDAD'].isin(['Rural', 'Urbano'])]
valores_invalidos3 = df_ciclo2[~df_ciclo2['DS_RURALIDAD'].isin(['Rural', 'Urbano'])]
valores_invalidos4 = df_media[~df_media['DS_RURALIDAD'].isin(['Rural', 'Urbano'])]

#valores_invalidos1
#valores_invalidos2
#valores_invalidos3
#valores_invalidos4

# %%
mostrar_weas_Del_dataframio(df_parvularia)
# Out:
# Filas y columnas: (6163, 21)
# Duplicados: 0
# Nulos por columna:
#  ID_RBD                      0
# DV_RBD                      0
# DS_NOM_ESTABLE              0
# DS_TIPO_DEPENDENCIA         0
# DS_RURALIDAD                0
# ID_REGION_ESTABLE           0
# ID_PROVINCIA_ESTABLE        0
# ID_COMUNA_ESTABLE           0
# DS_COMUNA_ESTABLE           0
# N EVALUADO                  0
# IVM Establecimiento         0
# IVM Bajo                    0
# IVM Medio                   0
# IVM Alto                    0
# IVM Muy Alto                0
# IVM Salud                   0
# IVM CSE Familiar            0
# IVM Estimulación y Apoyo    0
# IVM Familia                 0
# IVM CSE Comunal             0
# IVM Derechos                0
# dtype: int64
# Tipos de datos:
#  ID_RBD                        int64
# DV_RBD                        int64
# DS_NOM_ESTABLE               object
# DS_TIPO_DEPENDENCIA          object
# DS_RURALIDAD                 object
# ...

# %%
mostrar_weas_Del_dataframio(df_parvularia)
# Out:
# Filas y columnas: (6163, 21)
# Duplicados: 0
# Nulos por columna:
#  ID_RBD                      0
# DV_RBD                      0
# DS_NOM_ESTABLE              0
# DS_TIPO_DEPENDENCIA         0
# DS_RURALIDAD                0
# ID_REGION_ESTABLE           0
# ID_PROVINCIA_ESTABLE        0
# ID_COMUNA_ESTABLE           0
# DS_COMUNA_ESTABLE           0
# N EVALUADO                  0
# IVM Establecimiento         0
# IVM Bajo                    0
# IVM Medio                   0
# IVM Alto                    0
# IVM Muy Alto                0
# IVM Salud                   0
# IVM CSE Familiar            0
# IVM Estimulación y Apoyo    0
# IVM Familia                 0
# IVM CSE Comunal             0
# IVM Derechos                0
# dtype: int64
# Tipos de datos:
#  ID_RBD                        int64
# DV_RBD                        int64
# DS_NOM_ESTABLE               object
# DS_TIPO_DEPENDENCIA          object
# DS_RURALIDAD                 object
# ...

# %%
mostrar_weas_Del_dataframio(df_ciclo1)
# Out:
# Filas y columnas: (7082, 23)
# Duplicados: 0
# Nulos por columna:
#  ID_RBD                  0
# DV_RBD                  0
# DS_NOM_ESTABLE          0
# DS_TIPO_DEPENDENCIA     0
# DS_RURALIDAD            0
# ID_REGION_ESTABLE       0
# ID_PROVINCIA_ESTABLE    0
# ID_COMUNA_ESTABLE       0
# DS_COMUNA_ESTABLE       0
# N EVALUADO              0
# IVM Establecimiento     0
# IVM Bajo                0
# IVM Medio               0
# IVM Alto                0
# IVM Muy Alto            0
# IVM Salud               0
# IVM Discapacidad        0
# IVM Educación           0
# IVM Habitabilidad       0
# IVM Familiar            0
# IVM Participación       0
# IVM CSE Familia         0
# IVM CSE Comunal         0
# dtype: int64
# Tipos de datos:
#  ID_RBD                    int64
# DV_RBD                    int64
# DS_NOM_ESTABLE           object
# DS_TIPO_DEPENDENCIA      object
# DS_RURALIDAD             object
# ID_REGION_ESTABLE         int64
# ID_PROVINCIA_ESTABLE      int64
# ...

# %%
mostrar_weas_Del_dataframio(df_ciclo2)
# Out:
# Filas y columnas: (5662, 15)
# Duplicados: 0
# Nulos por columna:
#  ID_RBD                  0
# DV_RBD                  0
# DS_NOM_ESTABLE          0
# DS_TIPO_DEPENDENCIA     0
# DS_RURALIDAD            0
# ID_REGION_ESTABLE       0
# ID_PROVINCIA_ESTABLE    0
# ID_COMUNA_ESTABLE       0
# DS_COMUNA_ESTABLE       0
# N EVALUADO              0
# IVM Establecimiento     0
# IVM Bajo                0
# IVM Medio               0
# IVM Alto                0
# IVM Muy Alto            0
# dtype: int64
# Tipos de datos:
#  ID_RBD                    int64
# DV_RBD                    int64
# DS_NOM_ESTABLE           object
# DS_TIPO_DEPENDENCIA      object
# DS_RURALIDAD             object
# ID_REGION_ESTABLE         int64
# ID_PROVINCIA_ESTABLE      int64
# ID_COMUNA_ESTABLE         int64
# DS_COMUNA_ESTABLE        object
# N EVALUADO                int64
# IVM Establecimiento     float64
# IVM Bajo                  int64
# IVM Medio                 int64
# IVM Alto                  int64
# ...

# %%
mostrar_weas_Del_dataframio(df_media)
# Out:
# Filas y columnas: (2618, 15)
# Duplicados: 0
# Nulos por columna:
#  ID_RBD                  0
# DV_RBD                  0
# DS_NOM_ESTABLE          0
# DS_TIPO_DEPENDENCIA     0
# DS_RURALIDAD            0
# ID_REGION_ESTABLE       0
# ID_PROVINCIA_ESTABLE    0
# ID_COMUNA_ESTABLE       0
# DS_COMUNA_ESTABLE       0
# N EVALUADO              0
# IVM Establecimiento     0
# IVM Bajo                0
# IVM Medio               0
# IVM Alto                0
# IVM Muy Alto            0
# dtype: int64
# Tipos de datos:
#  ID_RBD                    int64
# DV_RBD                    int64
# DS_NOM_ESTABLE           object
# DS_TIPO_DEPENDENCIA      object
# DS_RURALIDAD             object
# ID_REGION_ESTABLE         int64
# ID_PROVINCIA_ESTABLE      int64
# ID_COMUNA_ESTABLE         int64
# DS_COMUNA_ESTABLE        object
# N EVALUADO                int64
# IVM Establecimiento     float64
# IVM Bajo                  int64
# IVM Medio                 int64
# IVM Alto                  int64
# ...

# %%
#Respuesta a) 
print(f'df_parvularia: {len(df_parvularia)} Lineas\ndf_ciclo1: {len(df_ciclo1)} Lineas\ndf_ciclo2: {len(df_ciclo2)} Lineas\ndf_media: {len(df_media)} Lineas')
# Out:
# df_parvularia: 6163 Lineas
# df_ciclo1: 7082 Lineas
# df_ciclo2: 5662 Lineas
# df_media: 2618 Lineas

# %%
#Respuesta b)
print(df_parvularia.memory_usage().sum())
print(df_ciclo1.memory_usage().sum())
print(df_ciclo2.memory_usage().sum())
print(df_media.memory_usage().sum())
# Out:
# 1035516
# 1303220
# 679572
# 314292

# %%
print(df_parvularia.columns)
print(df_ciclo1.columns)
print(df_ciclo2.columns)
print(df_media.columns)
# Out:
# Index(['ID_RBD', 'DV_RBD', 'DS_NOM_ESTABLE', 'DS_TIPO_DEPENDENCIA',
#        'DS_RURALIDAD', 'ID_REGION_ESTABLE', 'ID_PROVINCIA_ESTABLE',
#        'ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'N EVALUADO',
#        'IVM Establecimiento', 'IVM Bajo', 'IVM Medio', 'IVM Alto',
#        'IVM Muy Alto', 'IVM Salud', 'IVM CSE Familiar',
#        'IVM Estimulación y Apoyo', 'IVM Familia', 'IVM CSE Comunal',
#        'IVM Derechos'],
#       dtype='object')
# Index(['ID_RBD', 'DV_RBD', 'DS_NOM_ESTABLE', 'DS_TIPO_DEPENDENCIA',
#        'DS_RURALIDAD', 'ID_REGION_ESTABLE', 'ID_PROVINCIA_ESTABLE',
#        'ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'N EVALUADO',
#        'IVM Establecimiento', 'IVM Bajo', 'IVM Medio', 'IVM Alto',
#        'IVM Muy Alto', 'IVM Salud', 'IVM Discapacidad', 'IVM Educación',
#        'IVM Habitabilidad', 'IVM Familiar', 'IVM Participación',
#        'IVM CSE Familia', 'IVM CSE Comunal'],
#       dtype='object')
# ...

# %%
#Respuesta c)
df_parvularia["N EVALUADO"] = pd.to_numeric(df_parvularia["N EVALUADO"], errors="coerce")
print(df_parvularia["N EVALUADO"].sum())

df_ciclo1["N EVALUADO"] = pd.to_numeric(df_ciclo1["N EVALUADO"], errors="coerce")
print(df_ciclo1["N EVALUADO"].sum())

df_ciclo2["N EVALUADO"] = pd.to_numeric(df_ciclo2["N EVALUADO"], errors="coerce")
print(df_ciclo2["N EVALUADO"].sum())

df_media["N EVALUADO"] = pd.to_numeric(df_media["N EVALUADO"], errors="coerce")
print(df_media["N EVALUADO"].sum())
# Out:
# 255506
# 882881
# 484540
# 901899

# %% [markdown]
# ### 3.2 Datos geográficos (0.5 puntos)
#
# Cargue en un GeoDataFrame de GeoPandas la información de los polígonos de cada comuna del país.
#
# Como realizamos en la Tarea pasada, puede transformar el Coordinate Reference System (CRS) a EPSG 4326, para tener la información de los puntos de los polígonos con latitud y longitud.

# %%
# %pwd
# Out:
# 'c:\\GIT HUB DESKO\\IMT2200-Lucas-Chicao\\Tareas\\Tarea 3\\data\\Comunas'

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9E56-4120
#
#  Directory of c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3\data\Comunas
#
# 10/27/2025  02:43 AM    <DIR>          .
# 10/27/2025  02:43 AM    <DIR>          ..
# 06/14/2019  01:46 PM                 5 comunas.CPG
# 06/14/2019  01:47 PM            93,114 comunas.dbf
# 05/14/2019  12:25 PM               425 comunas.prj
# 06/14/2019  01:46 PM             3,340 comunas.sbn
# 06/14/2019  01:46 PM               228 comunas.sbx
# 06/14/2019  01:46 PM        63,994,252 comunas.shp
# 10/16/2019  10:55 AM            27,735 comunas.shp.xml
# 06/14/2019  01:46 PM             2,868 comunas.shx
#                8 File(s)     64,121,967 bytes
#                2 Dir(s)  20,038,266,880 bytes free

# %%
# %cd ..
# Out:
# c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3

# %%
# %cd Tarea 3
# Out:
# c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3

# %%
# %cd data
# Out:
# c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3\data

# %%
# %cd Comunas/
# Out:
# c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3\data\Comunas

# %%
# Respuesta
import geopandas as gpd
archivo = "comunas.shp"
gdf_comunas = gpd.read_file(archivo)
print(gdf_comunas.crs)
gdf_comunas = gdf_comunas.to_crs(epsg=4326)
print(gdf_comunas.crs)

print(gdf_comunas.columns)
# Out:
# EPSG:3857
# EPSG:4326
# Index(['objectid', 'shape_leng', 'dis_elec', 'cir_sena', 'cod_comuna',
#        'codregion', 'st_area_sh', 'st_length_', 'Region', 'Comuna',
#        'Provincia', 'geometry'],
#       dtype='object')

# %%
gdf_comunas.plot(figsize=(8, 8))
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Análisis descriptivo (1.5 puntos)
#
# En esta sección haremos una exploración preliminar de los 4 sets de datos cargados. Para cada una de las siguientes preguntas, sustente su respuesta con al menos un gráfico y su análisis respectivo.
#
# **Recomendación:** puede utilizar el método `subplots()` de `matplotlib.pyplot` para facilitar la visualización de múltiples gráficos a la vez.
#
# ### 4.1 Ruralidad (0.8 pts)
# * a. ¿Cuál es la cantidad de establecimientos rurales vs urbanos según nivel de enseñanza?
# * b. ¿Cómo se distribuye el IVM según nivel de enseñanza y ruralidad?

# %%
import matplotlib.pyplot as plt

# %%
#Respuesta a)

dataframes = [df_parvularia, df_ciclo1, df_ciclo2, df_media]
niveles = {"Parvularia": 0,
           "Primer Ciclo Básico" : 0,
           "Segundo Ciclo Básico" : 0,
           "Media" : 0
           }            
contador = 0
for i in niveles :
    niveles[i] = dataframes[contador]["DS_RURALIDAD"].value_counts()
    contador += 1
for i in niveles:
    print(i , niveles[i])
    print("-----------")
    print(f"Diferencia : {niveles[i][0] - niveles[i][1] } \n")
# Out:
# Parvularia DS_RURALIDAD
# Urbano    4903
# Rural     1260
# Name: count, dtype: int64
# -----------
# Diferencia : 3643
#
# Primer Ciclo Básico DS_RURALIDAD
# Urbano    4128
# Rural     2954
# Name: count, dtype: int64
# -----------
# Diferencia : 1174
#
# Segundo Ciclo Básico DS_RURALIDAD
# Urbano    4170
# Rural     1492
# Name: count, dtype: int64
# -----------
# Diferencia : 2678
#
# Media DS_RURALIDAD
# Urbano    2449
# Rural      169
# Name: count, dtype: int64
# -----------
# Diferencia : 2280
# C:\Users\lchicao\AppData\Local\Temp\ipykernel_2988\397960179.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Diferencia : {niveles[i][0] - niveles[i][1] } \n")

# %% [markdown]
# # Respuesta b)
#
# # Parvularia
#
# En rural la mediana esta sobre los 60 puntos, pero no por mucho, existen outliers antes del minimo y despues del maximo, predominando en el maximo, el 'cajon' esta centrado
#
# En Urbano la mediana esta bajo los 55 puntos, existen outliers antes del minimo y despues del maximo, sin poder notar un opredominante claro, el 'cajon esta centrado'
#
# El puntaje del IVM de rural es mayor en general sin contar outliers, si los llegamos a contar el promedio de rural puede variar
#
# # Primer ciclo basico
#
# En Rural, La mediana esta bajo los 45 puntos, el maximo esta bajo los 55, hay muchos outliers en ambos lados, el minimo esta por alrederos de los 35 puntos, hay outliers que estan muy cerca de los 20 puntos y otros sobre los 60 puntos, incluso uno llega a los 90 puntos
#
# En Urbano, la mediaana esta bajo los 45 puntos, el maximo esta bajo los 55, hay muy outliers despues del maximo
#
# Sin contar outliers, el puntaje IVM en general es ligeramente mas alto, contando outliers puede variar esta conclusion considerando la gran diferenia que puede haber, habiendo casos de <30 puntos y >60 puntos los cuales no se presentan en Urbano
#
# # Segundo ciclo Basico
#
# En Rural, la mediana esta bajo los 40 puntos, el maximo esta cerca de los 45 puntos, hay outliers en ambos lados, hay outliers cercanos a los 20 puntos bajo los 15, hay un outlier cerca de los 60, el 'cajon' esta centrado
#
# En Urbano, la mediana esta cerca de los 40 puntos, el 3cer cuartil esta sobre los 40 puntos por poco, el maximo esta sobre los 45 puntos por poco, hay outliers predomianndo sobre el maximo, hay un outlier que llega sobre 70 puntos
#
# En este caso, el puntaje IVM de urbano es predominantemente mayor a compraracion de rural
#
# # Media
#
# En rural,la mediana esta bajo los 50 puntos y el maximo esta cerca de los 25 puntos, hay solo 3 outliers bajo los 35 puntos, el minimo esta bajo los 20 puntos llegando casi a los 10
#
# En Urbano, La mediana esta bajo los 20 por poco, el maximo esta en los 30 puntos y hay muchos outliers sobre el maximo, hay un outlier que llega sobre los 60 casi 70, la mayoria de los outliers se concentra entre 30 y 40 puntos
#
# En este acso Urbano es superior considerablemente a comparacion de rural, si llegamos a contar lor outliers claro, por otro lado, Urbano tiene un minimo mas 'chico' que el de Rural

# %%
# Respuesta b)
niveles = ["Parvularia", "Primer Ciclo Básico", "Segundo Ciclo Básico", "Media"]
dataframios = [df_parvularia, df_ciclo1, df_ciclo2, df_media]

for i in range(4):
    plt.figure(figsize=(6, 5))
    dataframios[i].boxplot(column="IVM Establecimiento", by="DS_RURALIDAD")
    plt.title(f"Distribución del IVM según ruralidad ({niveles[i]})")
    plt.xlabel("Ruralidad")
    plt.ylabel("IVM Establecimiento")
    plt.show()

# %% [markdown]
# Respuesta y comentarios:

# %% [markdown]
# ### 4.2 Tipo de establecimiento (0.7 pts)
#
# * ¿Cómo es la distribución del IVM promedio de los establecimientos según tipo de dependencia y nivel de enseñanza?

# %% [markdown]
# # Respuesta 4.2
#
# # Parvularia
#
# Estan todos parejos, bajo los 60 puntos y sobre los 50 puntos, teniendo al mayor IVM con Municipal DAEM
#
# # Primer ciclo basico
#
# Estan todos bajo los 50 puntos, Admin.Delegada esta bajo los 40 puntos por poco, en general estan bastante parejos
#
# # Segundo Ciclo Basico
#
# Estan todos bajo los 40 puntos pero sobre los 35 puntos, estan todos bastante parejos
#
# # Media
#
# Estan todo bajo los 25 puntos, y el mas bajo es particulas subencionado que esta bajo los 20 puntos, pero sobre los 15
# el mayor parece ser Administracion Delegada o Corporacion Municipal, no se nota mucho la diferencia entre los 2,

# %%
# respuestas

niveles = ["Parvularia", "Primer Ciclo Básico", "Segundo Ciclo Básico", "Media"]
dataframios = [df_parvularia, df_ciclo1, df_ciclo2, df_media]

for i in range(4):
    dataframio = dataframios[i]
    promedio_ivm = dataframio.groupby("DS_TIPO_DEPENDENCIA")["IVM Establecimiento"].mean().sort_values()
    plt.figure(figsize=(8, 5))
    promedio_ivm.plot(kind="bar")
    
    plt.title(f"IVM promedio según dependencia ({niveles[i]})")
    plt.xlabel("Tipo de dependencia")
    plt.ylabel("IVM promedio")
    plt.xticks(rotation=45, ha="right")
    plt.show()

# %% [markdown]
# Respuesta y comentarios:

# %% [markdown]
# ### 4.3 Pregunta Bono: Dimensiones de vulnerabilidad (1 punto)
#
# Para los niveles de enseñanza Parvularia y Básica Primer ciclo (1-4º), tenemos información sobre distintas dimensiones de que se utilizan para calcular el IVM, como condición socioeconómica familiar y comunal, salud, etc.
#
# * Para todo Chile, en promedio, ¿cuál es la dimensión con mayor puntaje de IVM para cada uno de estos dos niveles de enseñanza?

# %%
# Respuestas

# %% [markdown]
# Respuesta y comentarios:

# %% [markdown]
# ## 5. Agrupación de bases de datos (2 puntos)
#
# El objetivo de esta sección será agrupar los establecimientos según la comuna en la que se encuentran para obtener un resumen general sobre la vulnerabilidad escolar en cada una de ellas. Al finalizar esta sección, tendremos un nuevo DataFrame `agg_comunal` que contenga, al menos, la siguiente información:
#
# * Comuna (nombre y ID)
# * Región (ID)
# * Cantidad de establecimientos rurales de la comuna
# * Cantidad de establecimientos urbanos de la comuna
# * Cantidad total de establecimientos de la comuna
# * Porcentaje de establecimientos rurales
# * IVM Promedio Parvularia de la comuna
# * IVM Promedio Básica Primer Ciclo de la comuna
# * IVM Promedio Básica Segundo Ciclo de la comuna
# * IVM Promedio Media de la comuna
# * Objeto geometry de GeoPandas correspondiente al polígono de la comuna respectiva
#
# Armaremos este DataFrame paso a paso.
#
# ### 5.1 Cálculo de IVM promedio por comuna (0.8 pts)
#
# Primero, para cada uno sus 4 DataFrames, calcule el promedio de la columna `IVM Establecimiento` según comuna. Almacene este valor en una nueva columna llamada `IVM Promedio {NIVEL DE ENSEÑANZA}` (por ejemplo, para enseñanza parvularia, cree la columna `IVM Promedio Parvularia`).
#
# Junte los 4 resultados que obtuvo en un solo DataFrame `ivm_comunal` que contenga:
# * Comuna (nombre y ID)
# * Región (ID)
# * IVM Promedio Parvularia de la comuna
# * IVM Promedio Básica Primer Ciclo de la comuna
# * IVM Promedio Básica Segundo Ciclo de la comuna
# * IVM Promedio Media de la comuna
#
# Ponga siempre atención al tamaño de sus DataFrames: como estamos agrupando comunalmente, estos siempre debiesen tener una cantidad de filas igual a las comunas de Chile.

# %%
# respuestas

ivm_1 = df_parvularia.groupby(
    ['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'ID_REGION_ESTABLE']
)['IVM Establecimiento'].mean().reset_index().rename(
    columns={'IVM Establecimiento': 'IVM_promedio_parvu'})


ivm_2 = df_ciclo1.groupby(
    ['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'ID_REGION_ESTABLE']
)['IVM Establecimiento'].mean().reset_index().rename(
    columns={'IVM Establecimiento': 'IVM_promedio_1ciclo'})



ivm_3 = df_ciclo2.groupby(
    ['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'ID_REGION_ESTABLE']
)['IVM Establecimiento'].mean().reset_index().rename(
    columns={'IVM Establecimiento': 'IVM_promedio_2ciclo'})



ivm_4 = df_media.groupby(
    ['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'ID_REGION_ESTABLE']
)['IVM Establecimiento'].mean().reset_index().rename(
    columns={'IVM Establecimiento': 'IVM_promedio_media'})


ivm_general = (
    ivm_1
    .merge(ivm_2, on=['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'ID_REGION_ESTABLE'], how='outer')
    .merge(ivm_3, on=['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'ID_REGION_ESTABLE'], how='outer')
    .merge(ivm_4, on=['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'ID_REGION_ESTABLE'], how='outer')
)

'''
* Comuna (nombre y ID)
* Región (ID)
* IVM Promedio Parvularia de la comuna
* IVM Promedio Básica Primer Ciclo de la comuna
* IVM Promedio Básica Segundo Ciclo de la comuna
* IVM Promedio Media de la comuna

aun que la wea en si no pedia id de la region lo decia mas arribita donde lo pide asi que lo deje por si acaso
'''

ivm_general
# Out:
#      ID_COMUNA_ESTABLE DS_COMUNA_ESTABLE  ID_REGION_ESTABLE  \
# 0                 1101           Iquique                  1
# 1                 1107     Alto Hospicio                  1
# 2                 1401      Pozo Almonte                  1
# 3                 1402            Camiña                  1
# 4                 1403          Colchane                  1
# ..                 ...               ...                ...
# 340              16301        San Carlos                 16
# 341              16302          Coihueco                 16
# 342              16303            Ñiquén                 16
# 343              16304        San Fabián                 16
# 344              16305       San Nicolás                 16
#
#      IVM_promedio_parvu  IVM_promedio_1ciclo  IVM_promedio_2ciclo  \
# 0             50.882970            45.131982            39.182182
# 1             55.419776            46.599904            41.289463
# ...

# %% [markdown]
# ### 5.2 Establecimientos por comuna y ruralidad (0.8 pts)
#
# Ahora contaremos la cantidad de establecimientos por comuna según ruralidad. Como buscamos la cantidad total de establecimientos, consideramos establecimientos de todos los niveles educacionales vistos. Para esto, combine los 4 DataFrames que cargó y genere un nuevo DataFrame `estab_comunal` que contenga:
#
# * Comuna (ID)
# * Cantidad de establecimientos rurales
# * Cantidad de establecimientos urbanos
# * Cantidad total de establecimientos
# * Porcentaje de establecimientos rurales (Establecimientos rurales / Total establecimientos * 100)
#
# Tenga en cuenta de que pueden aparecer establecimientos duplicados al combinar estos 4 DataFrames (por ejemplo, establecimientos que imparten múltiples niveles de enseñanza, desde 1º básico hasta 4º medio). Preocúpese de manejar estos casos antes de agrupar sus datos según ruralidad.

# %%
# respuestas

todito = pd.concat([df_parvularia, df_ciclo1,df_ciclo2, df_media], ignore_index=True)
todito.duplicated(subset="ID_RBD") #Con esto veo si hay duplicados y si, los hay

# Como buscamos la cantidad total de establecimientos
todito_nodupli = todito.drop_duplicates(subset='ID_RBD')

conteo = todito_nodupli.groupby(
    ['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'DS_RURALIDAD']
).size().reset_index(name='Cantidad')

def mea_wea(grupo):
    rural = grupo.loc[grupo['DS_RURALIDAD'] == 'Rural', 'Cantidad'].sum()
    urbano = grupo.loc[grupo['DS_RURALIDAD'] == 'Urbano', 'Cantidad'].sum()
    total = rural + urbano
    
    if total > 0 :
        porcentaje = (rural / total) * 100
    else :
        porcentaje = 0    
    return pd.Series({
        'Cantidad_Rural': rural,
        'Cantidad_Urbano': urbano,
        'Cantidad_Total': total,
        '%_Rural': porcentaje
    })

resultito = conteo.groupby(['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE']).apply(mea_wea).reset_index()
resultito
# Out:
# C:\Users\lchicao\AppData\Local\Temp\ipykernel_2988\3104811709.py:29: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   resultito = conteo.groupby(['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE']).apply(mea_wea).reset_index()
#      ID_COMUNA_ESTABLE DS_COMUNA_ESTABLE  Cantidad_Rural  Cantidad_Urbano  \
# 0                 1101           Iquique             3.0             81.0
# 1                 1107     Alto Hospicio             3.0             41.0
# 2                 1401      Pozo Almonte            12.0              0.0
# 3                 1402            Camiña            10.0              0.0
# 4                 1403          Colchane             4.0              0.0
# ...

# %% [markdown]
# ### 5.3 Unión de bases de datos y polígonos (0.4 pts)
#
# Finalmente, vamos a generar el DataFrame `agg_comunal` con la información de los dos previos DataFrames creados.
# Combine la información de las dos secciones anteriores para crear su base de datos unificada. Por último, agregue la columna `geometry` con la información geográfica de cada comuna.

# %%
# respuestas

agg_comunal = pd.merge(
    ivm_general,
    resultito,
    how='inner'
)

agg_comunal
# Out:
#      ID_COMUNA_ESTABLE DS_COMUNA_ESTABLE  ID_REGION_ESTABLE  \
# 0                 1101           Iquique                  1
# 1                 1107     Alto Hospicio                  1
# 2                 1401      Pozo Almonte                  1
# 3                 1402            Camiña                  1
# 4                 1403          Colchane                  1
# ..                 ...               ...                ...
# 340              16301        San Carlos                 16
# 341              16302          Coihueco                 16
# 342              16303            Ñiquén                 16
# 343              16304        San Fabián                 16
# 344              16305       San Nicolás                 16
#
#      IVM_promedio_parvu  IVM_promedio_1ciclo  IVM_promedio_2ciclo  \
# 0             50.882970            45.131982            39.182182
# 1             55.419776            46.599904            41.289463
# ...

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9E56-4120
#
#  Directory of c:\GIT HUB DESKO\IMT2200-Lucas-Chicao\Tareas\Tarea 3\data\Comunas
#
# 10/27/2025  02:43 AM    <DIR>          .
# 10/27/2025  02:43 AM    <DIR>          ..
# 06/14/2019  01:46 PM                 5 comunas.CPG
# 06/14/2019  01:47 PM            93,114 comunas.dbf
# 05/14/2019  12:25 PM               425 comunas.prj
# 06/14/2019  01:46 PM             3,340 comunas.sbn
# 06/14/2019  01:46 PM               228 comunas.sbx
# 06/14/2019  01:46 PM        63,994,252 comunas.shp
# 10/16/2019  10:55 AM            27,735 comunas.shp.xml
# 06/14/2019  01:46 PM             2,868 comunas.shx
#                8 File(s)     64,121,967 bytes
#                2 Dir(s)  19,473,719,296 bytes free

# %%
import geopandas as gpd
archivo = "comunas.shp"
gdf_comunas = gpd.read_file(archivo)
print(gdf_comunas.crs)
gdf_comunas = gdf_comunas.to_crs(epsg=4326)
print(gdf_comunas.crs)
print(gdf_comunas.columns)
# Out:
# EPSG:3857
# EPSG:4326
# Index(['objectid', 'shape_leng', 'dis_elec', 'cir_sena', 'cod_comuna',
#        'codregion', 'st_area_sh', 'st_length_', 'Region', 'Comuna',
#        'Provincia', 'geometry'],
#       dtype='object')

# %%
agg_comunal_gpd = agg_comunal.merge(
    gdf_comunas[['cod_comuna', 'geometry']],
    left_on='ID_COMUNA_ESTABLE',
    right_on='cod_comuna',
    how='left'
)

agg_comunal_gpd

# Se puede ver que ID_COMUNA_ESTABLE es igual a cod_comuna, aun que sea redundante, las voy a dejar a ambas
# Out:
#      ID_COMUNA_ESTABLE DS_COMUNA_ESTABLE  ID_REGION_ESTABLE  \
# 0                 1101           Iquique                  1
# 1                 1107     Alto Hospicio                  1
# 2                 1401      Pozo Almonte                  1
# 3                 1402            Camiña                  1
# 4                 1403          Colchane                  1
# ..                 ...               ...                ...
# 340              16301        San Carlos                 16
# 341              16302          Coihueco                 16
# 342              16303            Ñiquén                 16
# 343              16304        San Fabián                 16
# 344              16305       San Nicolás                 16
#
#      IVM_promedio_parvu  IVM_promedio_1ciclo  IVM_promedio_2ciclo  \
# 0             50.882970            45.131982            39.182182
# 1             55.419776            46.599904            41.289463
# ...

# %% [markdown]
# ## 6. Análisis de vulnerabilidad por comuna (1.5 puntos)
#
# ### 6.1 Mapa de calor (0.8 pts)
#
# Genere mapas de calor de las comunas de Chile según el IVM promedio de los establecimientos educacionales. Realice esto para cada etapa de enseñanza (Parvularia, Básica 1, Básica 2 y Media). Analice y comente sus resultados:
# * ¿Cómo se diferencia la vulnerabilidad en distintos sectores del país según nivel de enseñanza?

# %%
agg_comunal_gpd.columns
# Out:
# Index(['ID_COMUNA_ESTABLE', 'DS_COMUNA_ESTABLE', 'ID_REGION_ESTABLE',
#        'IVM_promedio_parvu', 'IVM_promedio_1ciclo', 'IVM_promedio_2ciclo',
#        'IVM_promedio_media', 'Cantidad_Rural', 'Cantidad_Urbano',
#        'Cantidad_Total', '%_Rural', 'cod_comuna', 'geometry'],
#       dtype='object')

# %%
# Respuesta Parvularia

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(
    agg_comunal_gpd['ID_COMUNA_ESTABLE'],
    agg_comunal_gpd['IVM_promedio_parvu'],
    alpha=0.2
)
ax.set_title("IVM promedio educación Parvularia", fontsize=12)
ax.set_xlabel("ID de Comuna")
ax.set_ylabel("IVM promedio")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(
    agg_comunal_gpd['ID_COMUNA_ESTABLE'],
    agg_comunal_gpd['IVM_promedio_1ciclo'],
    alpha=0.2
)
ax.set_title("IVM promedio educación 1 Ciclo Basica", fontsize=12)
ax.set_xlabel("ID de Comuna")
ax.set_ylabel("IVM promedio")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(
    agg_comunal_gpd['ID_COMUNA_ESTABLE'],
    agg_comunal_gpd['IVM_promedio_2ciclo'],
    alpha=0.2
)
ax.set_title("IVM promedio educación 2 Ciclo Basica", fontsize=12)
ax.set_xlabel("ID de Comuna")
ax.set_ylabel("IVM promedio")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(
    agg_comunal_gpd['ID_COMUNA_ESTABLE'],
    agg_comunal_gpd['IVM_promedio_media'],
    alpha=0.2
)
ax.set_title("IVM promedio educación Media", fontsize=12)
ax.set_xlabel("ID de Comuna")
ax.set_ylabel("IVM promedio")
plt.show()

# %% [markdown]
# # Comentarios y análisis:
#
# Es difil analizar de esta forma ya que no lo hice por region, le puse un alpha=0.2 que hace que se vean trasparentes y por lo tanto podamos ver las concentraciones

# %% [markdown]
# ### 6.2 Relación entre ruralidad comunal y vulnerabilidad (0.7 pts)
#
# En la sección **5.2** definimos el **porcentaje de ruralidad** de cada comuna según la cantidad de establecimientos rurales en cada una. Analice y visualice los datos en `agg_comunal` para responder la siguiente pregunta:
#
# * ¿Hay alguna correlación entre el IVM promedio y el porcentaje de ruralidad en las comunas de Chile?

# %%
# respuestas

# %% [markdown]
# ## 7 Pregunta Bono (2 punto)
#
# * Proponga una pregunta de análisis que le interese responder con los datos de cualquiera de las bases de datos leídas o generadas durante esta Tarea.
# Respóndala de la misma forma que las preguntas anteriores, generando una o varias visualizaciones y analizando sus resultados. Justifique
#
# **Recomendación**: Trate de proponer una pregunta que justifique el uso de agregación de datos y visualización. En otras palabras, que
# no pueda ser respondida directamente sin el uso de gráficos (por ejemplo, *"¿cuál es el establecimiento con mayor IVM?"* puede ser respondida con una búsqueda rápida en el DataFrame).

# %% [markdown]
# **Pregunta propuesta:**

# %%
# respuesta
